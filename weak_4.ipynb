# %%
''' 1. Functions are often used to validate input. Write a function that accepts a single
integer as a parameter and returns True if the integer is in the range 0 to 100
(inclusive), or False otherwise. Write a short program to test the function.'''

def function_num(num):
    return 0 <= num <= 100
number = int(input("enter a number between (o to 100):"))

if function_num(number):
    print("True")
else:
    print("False")
# Out:
# enter a number between (o to 100): 102
# False

# %%
''' 2. Write a function that has a single string as its parameter, and returns the number of
uppercase letters, and the number of lowercase letters in the string. Test the
function with a short program. '''


def count_case(text):
    upper_count = 0
    lower_count = 0

    for char in text:
        if char.isupper():
            upper_count += 1
        elif char.islower():
            lower_count += 1

    return upper_count, lower_count


# test the function
string = input("Enter a string: ")

u, l = count_case(string)

print("Uppercase letters:", u)
print("Lowercase letters:", l)
# Out:
# Enter a string:  ABHIshek
# Uppercase letters: 4
# Lowercase letters: 4

# %%
''' 3. Modify your "greetings" program so that the first letter of the name entered is
always in uppercase with the rest in lowercase. This should happen even if the user
entered their name differently. So if the user entered arthur, ARTHUR, or even
arTHur the name should be displayed as Arthur.'''


def first_letter(word):
    first = word [0].upper()
    rest = word [1:].lower()
    return first + rest
value = input("Enter any word you like:")
result = first_letter(value)
print("you entered word", value)
print("result:",result)
# Out:
# Enter any word you like: abhIsHek
# you entered word abhIsHek
# result: Abhishek

# %%
''' 4. When processing data it is often useful to remove the last character from some
input (it is often a newline). Write and test a function that takes a string parameter
and returns it with the last character removed. (If the string contains one or fewer
characters, return it unchanged.) '''
def last_letter(data):
    if len(data) <= 1:
        return data
    return data [:-1]
text = input("enter a string value:")
print(last_letter(text))
# Out:
# enter a string value: abhishek
# abhishe

# %%
''' 5. Write and test a function that converts a temperature measured in degrees
centigrade into the equivalent in fahrenheit, and another that does the reverse
conversion. Test both functions. (Google will find you the formulae).'''
# Celsius to Fahrenheit
def c_to_f(c):
    return (9/5) * c + 32

# Fahrenheit to Celsius
def f_to_c(f):
    return (5/9) * (f - 32)


# using loop
while True:
    temp = input("Enter a temperature (C/F/Q): ").upper()

    if temp == "C":
        c = float(input("Enter a value in Celsius: "))
        print("Fahrenheit:", c_to_f(c))

    elif temp == "F":
        f = float(input("Enter a value in Fahrenheit: "))
        print("Celsius:", f_to_c(f))

    elif temp not in ("C", "F", "Q"):
        print("Invalid input!!")
        continue

    elif temp == "Q":
        break
# Out:
# Enter a temperature (C/F/Q):  c
# Enter a value in Celsius:  22.4
# Fahrenheit: 72.32
# Enter a temperature (C/F/Q):  q

# %%
''' 6. Write a program that takes a centigrade temperature and displays the equivalent in
fahrenheit. The input should be a number followed by a letter C. The output should
be in the same format.'''

temp = input("Enter a temperature in celsius:")
celsius = float(temp[:-1])

# convert to Fahrenheit
fahrenheit = (9/5) * celsius + 32
print(f"temperature in fahrenheit:{fahrenheit}F")
# Out:
# Enter a temperature in celsius: 25
# temperature in fahrenheit:35.6F

# %%
'''  7. Write a program that reads 6 temperatures (in the same format as before), and
displays the maximum, minimum, and mean of the values.
Hint: You should know there are built-in functions for max and min. If you hunt, you
might also find one for the mean.'''


temp = []
for i in range(6):
    temps = input(f"enter a temperature:{i+1}C :")
    value = float(temps[:-1])
    temp.append(value)
# calculate maximum, minimum, and mean
maximum = max(temp)
minimum = min(temp)
mean = sum(temp) / len(temp)
print("------RESULTS----")
# display results
print("Maximum temperature:", maximum, "C")
print("Minimum temperature:", minimum, "C")
print("Mean temperature:", mean, "C")
# Out:
# enter a temperature:1C : 23c
# enter a temperature:2C : 45c
# enter a temperature:3C : 56c
# enter a temperature:4C : 67c
# enter a temperature:5C : 68c
# enter a temperature:6C : 44c
# ------RESULTS----
# Maximum temperature: 68.0 C
# Minimum temperature: 23.0 C
# Mean temperature: 50.5 C

# %%
'''8. Modify the previous program so that it can process any number of values. The input
terminates when the user just pressed "Enter" at the prompt rather than entering a
value.'''

temps = []   

while True:
    temp = input("Enter a temperature (like: 25C) or press Enter to finish: ")

    # stop if user just presses Enter
    if temp == "":
        break

    # remove the last character (C) and convert to float
    value = float(temp[:-1])
    temps.append(value)

print("----RESULTS-------")
maximum = max(temps)
minimum = min(temps)
mean = sum(temps) / len(temps)

print("Maximum temperature:", maximum, "C")
print("Minimum temperature:", minimum, "C")
print("Mean temperature:", mean, "C")
# Out:
# Enter a temperature (like: 25C) or press Enter to finish:  98c
# Enter a temperature (like: 25C) or press Enter to finish:  45c
# Enter a temperature (like: 25C) or press Enter to finish:  12c
# Enter a temperature (like: 25C) or press Enter to finish:
# ----RESULTS-------
# Maximum temperature: 98.0 C
# Minimum temperature: 12.0 C
# Mean temperature: 51.666666666666664 C
